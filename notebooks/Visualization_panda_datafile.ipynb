# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd

# %%
df_1 = pd.HDFStore("/eos/user/v/vdurupt/test_1_davide/test_1_davide_object.h5py", "r")["df"]
df_1
# Out:
#        output_object.csv sc_matched  calomatched  caloindex  genmatched  \
# 0                    0.0       True          1.0        0.0         1.0
# 1                    1.0       True          1.0        3.0         1.0
# 2                    2.0       True          1.0        1.0         1.0
# 3                    3.0       True          1.0        2.0         1.0
# 4                    0.0       True          1.0        0.0         1.0
# ...                  ...        ...          ...        ...         ...
# 14253                0.0       True          1.0        3.0         1.0
# 14254                1.0       True          1.0        1.0         1.0
# 14255                3.0       True          1.0        0.0         1.0
# 14256                4.0       True          1.0        2.0         1.0
# 14257                NaN        NaN          NaN        NaN         NaN
#
#        genindex  sc_index  seed_index     en_seed    et_seed  ...  genpart_et  \
# ...
